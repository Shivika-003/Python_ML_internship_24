# %%
"""plt.figure(figure = (10,5))
plt.bar(tem['Name'],tem['English'],label="English")
plt.xlabel("Name",fontsize=15,colour
plt.ylabel("Marks",fontsize=15)
plt.title("Marks in English Subject",fontsize=20,color='g')
plt.legend()
plt.grid()
plt.show()"""
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
names = ['kavya', 'karma', 'bagdiyaansh','shivi','Amisha']
marks = [85, 90, 75,88,99]
plt.bar(names, marks)
plt.xlabel("Name", fontsize=15)
plt.ylabel("Marks", fontsize=15)
plt.title("Marks in English Subject", fontsize=20,color="g")
plt.legend(['Marks'])
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 5))
names = ['Ansh', 'Kavya', 'Karmanya','Amisha','Shivi']
marks = [98.9, 90, 75, 88, 99]
plt.pie(marks, labels=names, autopct='%1.1f%%', colors=plt.cm.Paired.colors)
plt.title("Marks in English Subject", fontsize=20, color="y")
plt. legend(['Ansh', 'Kavya', 'Karmanya','Amisha','Shivi'])
plt.show()
