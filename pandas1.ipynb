# %%
#pandas are used to clean, import,export data.
#1. series----> data in 1d array
#2. data frame--->data in 2d array in multi array.

dice={
    "Name":["Guli", "Kavya", "Karma", "Shivi", "MadalKuttaKamina"],
    "Roll No":[1,2,3,4,5],
    "Grades":["A", "B", "C", "C","B" ],
    "Email":["abc@xyz.com","def@xyz.com","ghi@xyz.com","jkl@xyz.com","BuraInsan@xyz.com"]}
print(dice)
import pandas as pd
df = pd.DataFrame(dice)
df
# Out:
# {'Name': ['Guli', 'Kavya', 'Karma', 'Shivi', 'MadalKuttaKamina'], 'Roll No': [1, 2, 3, 4, 5], 'Grades': ['A', 'B', 'C', 'C', 'B'], 'Email': ['abc@xyz.com', 'def@xyz.com', 'ghi@xyz.com', 'jkl@xyz.com', 'BuraInsan@xyz.com']}
#                Name  Roll No Grades              Email
# 0              Guli        1      A        abc@xyz.com
# 1             Kavya        2      B        def@xyz.com
# 2             Karma        3      C        ghi@xyz.com
# 3             Shivi        4      C        jkl@xyz.com
# 4  MadalKuttaKamina        5      B  BuraInsan@xyz.com

# %%
entries = [
    {'Company Name': 'FinEdge', 'Employee Name': 'Ethan Brown', 'Position': 'Data Analyst'},
    {'Company Name': 'FoodiesInc', 'Employee Name': 'Leo King', 'Position': 'Financial Advisor'},
    {'Company Name': 'RetailWorld', 'Employee Name': 'Rachel Green', 'Position': 'Data Analyst'},
    {'Company Name': 'MediCare', 'Employee Name': 'Uma Wilson', 'Position': 'Customer Service'},
    {'Company Name': 'TechCorp', 'Employee Name': 'Mila Grant', 'Position': 'Software Engineer'},
    {'Company Name': 'EduSmart', 'Employee Name': 'Leo King', 'Position': 'Marketing Specialist'},
    {'Company Name': 'RetailWorld', 'Employee Name': 'Quincy Roberts', 'Position': 'Customer Service'},
    {'Company Name': 'GreenEnergy', 'Employee Name': 'Cindy Rivera', 'Position': 'Marketing Specialist'},
    {'Company Name': 'FinEdge', 'Employee Name': 'Eva Bell', 'Position': 'Project Manager'},
    {'Company Name': 'GreenEnergy', 'Employee Name': 'Violet Rogers', 'Position': 'HR Manager'},
    {'Company Name': 'TechCorp', 'Employee Name': 'Charlie Davis', 'Position': 'Financial Advisor'},
    {'Company Name': 'EcoSolutions', 'Employee Name': 'Zoe Bennett', 'Position': 'Software Engineer'},
    {'Company Name': 'RetailWorld', 'Employee Name': 'Grace Reed', 'Position': 'HR Manager'},
    {'Company Name': 'EduSmart', 'Employee Name': 'Dan Morgan', 'Position': 'HR Manager'},
    {'Company Name': 'FinEdge', 'Employee Name': 'Victor Lopez', 'Position': 'Sales Representative'},
    {'Company Name': 'FoodiesInc', 'Employee Name': 'Uma Wilson', 'Position': 'Project Manager'},
    {'Company Name': 'RetailWorld', 'Employee Name': 'Olivia Young', 'Position': 'Financial Advisor'},
    {'Company Name': 'FinEdge', 'Employee Name': 'Tara Hayes', 'Position': 'Marketing Specialist'},
    {'Company Name': 'FinEdge', 'Employee Name': 'Uma Wilson', 'Position': 'Financial Advisor'},
    {'Company Name': 'FoodiesInc', 'Employee Name': 'Frank Hughes', 'Position': 'Data Analyst'},
    {'Company Name': 'HealthPlus', 'Employee Name': 'Victor Lopez', 'Position': 'Customer Service'},
    {'Company Name': 'FinEdge', 'Employee Name': 'Zoe Bennett', 'Position': 'Software Engineer'},
    {'Company Name': 'HealthPlus', 'Employee Name': 'Ian Lewis', 'Position': 'HR Manager'},
    {'Company Name': 'MediCare', 'Employee Name': 'Victor Lopez', 'Position': 'IT Support'},
    {'Company Name': 'GreenEnergy', 'Employee Name': 'Steve Gonzales', 'Position': 'IT Support'},
    {'Company Name': 'FoodiesInc', 'Employee Name': 'Rachel Green', 'Position': 'Sales Representative'},
    {'Company Name': 'HealthPlus', 'Employee Name': 'Zane Mitchell', 'Position': 'Customer Service'},
    {'Company Name': 'TravelLux', 'Employee Name': 'Paul Walker', 'Position': 'Data Analyst'},
    {'Company Name': 'EcoSolutions', 'Employee Name': 'Megan Scott', 'Position': 'Data Analyst'},
    {'Company Name': 'RetailWorld', 'Employee Name': 'Eva Bell', 'Position': 'Financial Advisor'},
    {'Company Name': 'TravelLux', 'Employee Name': 'Steve Gonzales', 'Position': 'Data Analyst'},
    {'Company Name': 'GreenEnergy', 'Employee Name': 'Karen Adams', 'Position': 'Sales Representative'},
    {'Company Name': 'HealthPlus', 'Employee Name': 'Anna Torres', 'Position': 'Sales Representative'},
    {'Company Name': 'EcoSolutions', 'Employee Name': 'Paul Walker', 'Position': 'Product Manager'},
    {'Company Name': 'FoodiesInc', 'Employee Name': 'Megan Scott', 'Position': 'Project Manager'},
    {'Company Name': 'GreenEnergy', 'Employee Name': 'Uma Wilson', 'Position': 'Software Engineer'},
    {'Company Name': 'MediCare', 'Employee Name': 'Kara Brooks', 'Position': 'Customer Service'},
    {'Company Name': 'MediCare', 'Employee Name': 'Grace Reed', 'Position': 'Sales Representative'},
    {'Company Name': 'TravelLux', 'Employee Name': 'Tina Baker', 'Position': 'IT Support'},
    {'Company Name': 'GreenEnergy', 'Employee Name': 'Henry Ward', 'Position': 'IT Support'}
]
#example of how to access the dictionary
for entry in entries:
    print(f"Company Name:{entry['Company Name']},Employee Name: {entry['Employee Name']}, Position: {entry['Position']}")
# Out:
# Company Name:FinEdge,Employee Name: Ethan Brown, Position: Data Analyst
# Company Name:FoodiesInc,Employee Name: Leo King, Position: Financial Advisor
# Company Name:RetailWorld,Employee Name: Rachel Green, Position: Data Analyst
# Company Name:MediCare,Employee Name: Uma Wilson, Position: Customer Service
# Company Name:TechCorp,Employee Name: Mila Grant, Position: Software Engineer
# Company Name:EduSmart,Employee Name: Leo King, Position: Marketing Specialist
# Company Name:RetailWorld,Employee Name: Quincy Roberts, Position: Customer Service
# Company Name:GreenEnergy,Employee Name: Cindy Rivera, Position: Marketing Specialist
# Company Name:FinEdge,Employee Name: Eva Bell, Position: Project Manager
# Company Name:GreenEnergy,Employee Name: Violet Rogers, Position: HR Manager
# Company Name:TechCorp,Employee Name: Charlie Davis, Position: Financial Advisor
# Company Name:EcoSolutions,Employee Name: Zoe Bennett, Position: Software Engineer
# ...

# %%
cd = pd.DataFrame(entries)
cd
# Out:
#     Company Name   Employee Name              Position
# 0        FinEdge     Ethan Brown          Data Analyst
# 1     FoodiesInc        Leo King     Financial Advisor
# 2    RetailWorld    Rachel Green          Data Analyst
# 3       MediCare      Uma Wilson      Customer Service
# 4       TechCorp      Mila Grant     Software Engineer
# 5       EduSmart        Leo King  Marketing Specialist
# 6    RetailWorld  Quincy Roberts      Customer Service
# 7    GreenEnergy    Cindy Rivera  Marketing Specialist
# 8        FinEdge        Eva Bell       Project Manager
# 9    GreenEnergy   Violet Rogers            HR Manager
# 10      TechCorp   Charlie Davis     Financial Advisor
# 11  EcoSolutions     Zoe Bennett     Software Engineer
# 12   RetailWorld      Grace Reed            HR Manager
# 13      EduSmart      Dan Morgan            HR Manager
# 14       FinEdge    Victor Lopez  Sales Representative
# 15    FoodiesInc      Uma Wilson       Project Manager
# ...

# %%
# xlrd and open excel are the libraries to handle Excel  files in pandas
entries.drop(2,axis=0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 # xlrd and open excel are the libraries to handle Excel  files in pandas
# ----> 2 entries.drop(2,axis=0,inplace=True)
#
# AttributeError: 'list' object has no attribute 'drop'
